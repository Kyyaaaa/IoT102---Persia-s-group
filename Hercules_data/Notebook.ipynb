# %%
import pandas as pd
df = pd.read_csv("6.csv", header=None, names=["Light(lux)", "Temperature(celsius)", "MQ135(ADC)"])
df.head()
# Out:
#    Light(lux)  Temperature(celsius)  MQ135(ADC)
# 0       46.75                 92.86         455
# 1       46.75                 92.86         454
# 2       46.75                 92.38         453
# 3       46.75                 92.38         453
# 4       46.27                 92.38         452

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Tạo index làm trục x (nếu chưa có thời gian)
df["Index"] = df.index

# Plot từng biểu đồ
columns = ["Light(lux)", "Temperature(celsius)", "MQ135(ADC)"]

for col in columns:
    plt.figure(figsize=(8, 4))
    sns.lineplot(data=df, x="Index", y=col)
    plt.title(f"{col} over time")
    plt.xlabel("Index")
    plt.ylabel(col)
    plt.grid(True)
    plt.show()
