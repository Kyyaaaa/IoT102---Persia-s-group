# %%
import pandas as pd
df = pd.read_csv("8.csv", header=None, names=["Light(lux)", "Temperature(celsius)", "MQ135(ADC)"])
df.head()
# Out:
#    Light(lux)  Temperature(celsius)  MQ135(ADC)
# 0       78.99                 92.86         307
# 1       78.99                 92.86         307
# 2       78.34                 92.86         307
# 3       78.34                 93.35         307
# 4       79.64                 92.86         307

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Tạo index làm trục x (nếu chưa có thời gian)
df["X axis"] = df.index

# Plot từng biểu đồ
columns = ["Light(lux)", "Temperature(celsius)", "MQ135(ADC)"]

for col in columns:
    plt.figure(figsize=(8, 4))
    sns.lineplot(data=df, x="X axis", y=col)
    plt.title(f"{col} over time")
    plt.xlabel("X axis")
    plt.ylabel(col)
    plt.grid(True)
    plt.show()
